# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppress CUDA warnings
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, MaxPooling2D, GlobalAveragePooling2D, Conv2D, Dropout, BatchNormalization, Activation, Input, Multiply, Add
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd
import seaborn as sns
import warnings

# Add warrnings
warnings.filterwarnings('ignore', category=UserWarning, module='keras')

# Print TensorFlow version and GPU availability
print("TensorFlow Version:", tf.__version__)
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))

# Initialize MirroredStrategy for multi-GPU training  (Using kaggle GPU T4 X2)
strategy = tf.distribute.MirroredStrategy()
print("Number of GPUs in strategy:", strategy.num_replicas_in_sync)

# Define paths to the dataset directories in Kaggle
train_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/train'
test_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/test'

# Verify dataset directories exist
if not os.path.exists(train_dir):
    raise FileNotFoundError(f"Training directory not found: {train_dir}")
if not os.path.exists(test_dir):
    raise FileNotFoundError(f"Test directory not found: {test_dir}")

# Build everything within the strategy scope
with strategy.scope():
    # Refined data augmentation for training and validation (can be a bit severe for normal training)
    train_val_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        shear_range=0.1,
        brightness_range=[0.9, 1.1],
        horizontal_flip=True,
        fill_mode='nearest',
        validation_split=0.3
    )

    # Load training data  (32 is good for T4 vram 16GB per GPU)
    training_data = train_val_datagen.flow_from_directory(
        train_dir,
        target_size=(224,224),
        color_mode='grayscale',
        class_mode='binary',
        batch_size=32,
        subset='training'
    )

    # Load validation data
    validation_data = train_val_datagen.flow_from_directory(
        train_dir,
        target_size=(224,224),
        color_mode='grayscale',
        class_mode='binary',
        batch_size=32,
        subset='validation'
    )

    # Test data generator (no augmentation, just rescaling)
    test_datagen = ImageDataGenerator(rescale=1./255)

    # Load test data
    testing_data = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224,224),
        color_mode='grayscale',
        class_mode='binary',
        batch_size=32,
        shuffle=False
    )

    # Print class indices and validation class distribution
    print("Class indices:", training_data.class_indices)
    print("Training class distribution:", np.bincount(training_data.classes))
    print("Validation class distribution:", np.bincount(validation_data.classes))

    # Adjusted class weights based on class distribution so model won't bias to class 1
    class_weight_dict = {0: 1.5, 1: 0.5}

    # Squeeze-and-Excitation (SE) Block for better detection for pneumonia hard patterns
    def se_block(input_tensor, reduction=16):
        channels = input_tensor.shape[-1]
        x = GlobalAveragePooling2D()(input_tensor)
        x = Dense(channels // reduction, activation='relu')(x)
        x = Dense(channels, activation='sigmoid')(x)
        x = Multiply()([input_tensor, x[:, None, None, :]])
        return x

    # Enhanced CNN with skip connections (It's considered too deep and a complex for normal training and can waste resources
    # and time for almost no development in results but suitable for medical problems)
    inputs = Input(shape=(224, 224, 1))

    # Block 1
    x = Conv2D(64, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Block 2
    identity = x
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    identity = Conv2D(128, (1, 1), padding='same')(identity)
    x = Add()([x, identity])
    x = Activation('relu')(x)
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Block 3
    identity = x
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    identity = Conv2D(256, (1, 1), padding='same')(identity)
    x = Add()([x, identity])
    x = Activation('relu')(x)
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Block 4
    identity = x
    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    identity = Conv2D(512, (1, 1), padding='same')(identity)
    x = Add()([x, identity])
    x = Activation('relu')(x)
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Block 5
    identity = x
    x = Conv2D(1024, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(1024, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    identity = Conv2D(1024, (1, 1), padding='same')(identity)
    x = Add()([x, identity])
    x = Activation('relu')(x)
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Block 6
    identity = x
    x = Conv2D(2048, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(2048, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    identity = Conv2D(2048, (1, 1), padding='same')(identity)
    x = Add()([x, identity])
    x = Activation('relu')(x)
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Classification head
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)

    # Compile the model with binary cross-entropy
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=0.00005),
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.000005)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')

# Train the model
history = model.fit(
    training_data,
    epochs=70,
    validation_data=validation_data,
    class_weight=class_weight_dict,
    callbacks=[early_stopping, reduce_lr, checkpoint]
)

# Load the best model
model.load_weights('/kaggle/working/best_model.keras')

# Evaluate the model on validation data
val_loss, val_accuracy, val_precision, val_recall = model.evaluate(validation_data)
print(f"Validation Accuracy After Restoring Best Weights: {val_accuracy:.4f}, Loss: {val_loss:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}")

# Evaluate the model on test data
test_loss, test_accuracy, test_precision, test_recall = model.evaluate(testing_data)
print(f"Test Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}")

# Predict on test data
predictions = model.predict(testing_data)
predicted_classes = (predictions > 0.5).astype(int).flatten()
true_classes = testing_data.classes

# Generate and plot confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig('/kaggle/working/confusion_matrix.png')
plt.show()

# Plot accuracy and loss curves
plt.figure(figsize=(12,4))

# Accuracy plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Loss plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.savefig('/kaggle/working/accuracy_loss_curves.png')
plt.show()

# Generate and print classification report for test set
print("\nClassification Report for Test Set:")
print(classification_report(true_classes, predicted_classes, target_names=['NORMAL', 'PNEUMONIA']))
# Out:
# TensorFlow Version: 2.18.0
# Num GPUs Available: 2
# Number of GPUs in strategy: 2
# Found 3652 images belonging to 2 classes.
# Found 1564 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Class indices: {'NORMAL': 0, 'PNEUMONIA': 1}
# Training class distribution: [ 939 2713]
# Validation class distribution: [ 402 1162]
# Epoch 1/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 126s 922ms/step - accuracy: 0.8013 - loss: 11.4415 - precision_1: 0.9345 - recall_1: 0.7895 - val_accuracy: 0.7327 - val_loss: 11.0389 - val_precision_1: 0.7327 - val_recall_1: 1.0000 - learning_rate: 5.0000e-05
# Epoch 2/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 810ms/step - accuracy: 0.8906 - loss: 9.4562 - precision_1: 0.9636 - recall_1: 0.8874 - val_accuracy: 0.7315 - val_loss: 11.8525 - val_precision_1: 0.7315 - val_recall_1: 1.0000 - learning_rate: 5.0000e-05
# Epoch 3/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 100s 848ms/step - accuracy: 0.9075 - loss: 7.8375 - precision_1: 0.9794 - recall_1: 0.8956 - val_accuracy: 0.7519 - val_loss: 10.6896 - val_precision_1: 0.7519 - val_recall_1: 1.0000 - learning_rate: 5.0000e-05
# Epoch 4/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 814ms/step - accuracy: 0.9260 - loss: 6.5122 - precision_1: 0.9782 - recall_1: 0.9194 - val_accuracy: 0.7340 - val_loss: 7.6537 - val_precision_1: 0.7340 - val_recall_1: 1.0000 - learning_rate: 5.0000e-05
# Epoch 5/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 101s 854ms/step - accuracy: 0.9283 - loss: 5.4128 - precision_1: 0.9808 - recall_1: 0.9212 - val_accuracy: 0.9297 - val_loss: 4.7630 - val_precision_1: 0.9717 - val_recall_1: 0.9337 - learning_rate: 5.0000e-05
# Epoch 6/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 101s 858ms/step - accuracy: 0.9376 - loss: 4.4825 - precision_1: 0.9882 - recall_1: 0.9282 - val_accuracy: 0.9527 - val_loss: 3.9272 - val_precision_1: 0.9910 - val_recall_1: 0.9451 - learning_rate: 5.0000e-05
# Epoch 7/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 806ms/step - accuracy: 0.9470 - loss: 3.7207 - precision_1: 0.9863 - recall_1: 0.9417 - val_accuracy: 0.8977 - val_loss: 3.3662 - val_precision_1: 0.8831 - val_recall_1: 0.9966 - learning_rate: 5.0000e-05
# Epoch 8/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 809ms/step - accuracy: 0.9543 - loss: 3.0835 - precision_1: 0.9858 - recall_1: 0.9533 - val_accuracy: 0.9335 - val_loss: 2.7826 - val_precision_1: 0.9943 - val_recall_1: 0.9146 - learning_rate: 5.0000e-05
# Epoch 9/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 101s 855ms/step - accuracy: 0.9614 - loss: 2.5658 - precision_1: 0.9883 - recall_1: 0.9588 - val_accuracy: 0.9540 - val_loss: 2.2929 - val_precision_1: 0.9906 - val_recall_1: 0.9445 - learning_rate: 5.0000e-05
# Epoch 10/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 100s 853ms/step - accuracy: 0.9623 - loss: 2.1494 - precision_1: 0.9904 - recall_1: 0.9588 - val_accuracy: 0.9808 - val_loss: 1.8621 - val_precision_1: 0.9894 - val_recall_1: 0.9842 - learning_rate: 5.0000e-05
# Epoch 11/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 97s 822ms/step - accuracy: 0.9621 - loss: 1.7961 - precision_1: 0.9897 - recall_1: 0.9593 - val_accuracy: 0.9335 - val_loss: 1.6752 - val_precision_1: 0.9944 - val_recall_1: 0.9162 - learning_rate: 5.0000e-05
# Epoch 12/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 813ms/step - accuracy: 0.9677 - loss: 1.5059 - precision_1: 0.9923 - recall_1: 0.9641 - val_accuracy: 0.9322 - val_loss: 1.4789 - val_precision_1: 0.9962 - val_recall_1: 0.9119 - learning_rate: 5.0000e-05
# Epoch 13/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 811ms/step - accuracy: 0.9631 - loss: 1.2754 - precision_1: 0.9900 - recall_1: 0.9598 - val_accuracy: 0.9348 - val_loss: 1.2205 - val_precision_1: 0.9907 - val_recall_1: 0.9207 - learning_rate: 5.0000e-05
# Epoch 14/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 800ms/step - accuracy: 0.9657 - loss: 1.0738 - precision_1: 0.9918 - recall_1: 0.9610 - val_accuracy: 0.8632 - val_loss: 1.2979 - val_precision_1: 1.0000 - val_recall_1: 0.8174 - learning_rate: 5.0000e-05
# Epoch 15/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 812ms/step - accuracy: 0.9622 - loss: 0.9163 - precision_1: 0.9908 - recall_1: 0.9578 - val_accuracy: 0.9258 - val_loss: 0.9246 - val_precision_1: 0.9962 - val_recall_1: 0.9044 - learning_rate: 5.0000e-05
# Epoch 16/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 809ms/step - accuracy: 0.9553 - loss: 0.7962 - precision_1: 0.9922 - recall_1: 0.9473 - val_accuracy: 0.9386 - val_loss: 0.7925 - val_precision_1: 0.9686 - val_recall_1: 0.9488 - learning_rate: 5.0000e-05
# Epoch 17/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 798ms/step - accuracy: 0.9694 - loss: 0.6725 - precision_1: 0.9897 - recall_1: 0.9690 - val_accuracy: 0.8606 - val_loss: 1.0160 - val_precision_1: 0.9979 - val_recall_1: 0.8154 - learning_rate: 5.0000e-05
# Epoch 18/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 808ms/step - accuracy: 0.9667 - loss: 0.5921 - precision_1: 0.9901 - recall_1: 0.9649 - val_accuracy: 0.9552 - val_loss: 0.6018 - val_precision_1: 0.9676 - val_recall_1: 0.9726 - learning_rate: 5.0000e-05
# Epoch 19/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 815ms/step - accuracy: 0.9729 - loss: 0.5082 - precision_1: 0.9932 - recall_1: 0.9702 - val_accuracy: 0.9757 - val_loss: 0.4610 - val_precision_1: 0.9830 - val_recall_1: 0.9846 - learning_rate: 5.0000e-05
# Epoch 20/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 805ms/step - accuracy: 0.9653 - loss: 0.4506 - precision_1: 0.9914 - recall_1: 0.9611 - val_accuracy: 0.9118 - val_loss: 0.5576 - val_precision_1: 1.0000 - val_recall_1: 0.8810 - learning_rate: 5.0000e-05
# Epoch 21/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 800ms/step - accuracy: 0.9772 - loss: 0.3767 - precision_1: 0.9958 - recall_1: 0.9731 - val_accuracy: 0.9591 - val_loss: 0.3956 - val_precision_1: 0.9590 - val_recall_1: 0.9860 - learning_rate: 5.0000e-05
# Epoch 22/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 798ms/step - accuracy: 0.9637 - loss: 0.3577 - precision_1: 0.9894 - recall_1: 0.9614 - val_accuracy: 0.7379 - val_loss: 1.6777 - val_precision_1: 0.9812 - val_recall_1: 0.6483 - learning_rate: 5.0000e-05
# Epoch 23/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 818ms/step - accuracy: 0.9638 - loss: 0.3359 - precision_1: 0.9878 - recall_1: 0.9633 - val_accuracy: 0.9693 - val_loss: 0.3045 - val_precision_1: 0.9840 - val_recall_1: 0.9736 - learning_rate: 5.0000e-05
# Epoch 24/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 802ms/step - accuracy: 0.9649 - loss: 0.2866 - precision_1: 0.9909 - recall_1: 0.9620 - val_accuracy: 0.9604 - val_loss: 0.3136 - val_precision_1: 0.9911 - val_recall_1: 0.9556 - learning_rate: 5.0000e-05
# Epoch 25/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 808ms/step - accuracy: 0.9688 - loss: 0.2654 - precision_1: 0.9907 - recall_1: 0.9667 - val_accuracy: 0.8875 - val_loss: 0.4703 - val_precision_1: 1.0000 - val_recall_1: 0.8511 - learning_rate: 5.0000e-05
# Epoch 26/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 812ms/step - accuracy: 0.9805 - loss: 0.2139 - precision_1: 0.9966 - recall_1: 0.9772 - val_accuracy: 0.8772 - val_loss: 0.4767 - val_precision_1: 0.8578 - val_recall_1: 1.0000 - learning_rate: 5.0000e-05
# Epoch 27/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 816ms/step - accuracy: 0.9707 - loss: 0.2136 - precision_1: 0.9903 - recall_1: 0.9703 - val_accuracy: 0.9731 - val_loss: 0.2066 - val_precision_1: 0.9813 - val_recall_1: 0.9830 - learning_rate: 5.0000e-05
# Epoch 28/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 806ms/step - accuracy: 0.9757 - loss: 0.1779 - precision_1: 0.9942 - recall_1: 0.9733 - val_accuracy: 0.9437 - val_loss: 0.2488 - val_precision_1: 0.9307 - val_recall_1: 1.0000 - learning_rate: 5.0000e-05
# Epoch 29/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 804ms/step - accuracy: 0.9753 - loss: 0.1605 - precision_1: 0.9930 - recall_1: 0.9738 - val_accuracy: 0.9616 - val_loss: 0.2257 - val_precision_1: 0.9963 - val_recall_1: 0.9505 - learning_rate: 5.0000e-05
# Epoch 30/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 812ms/step - accuracy: 0.9751 - loss: 0.1486 - precision_1: 0.9926 - recall_1: 0.9739 - val_accuracy: 0.8951 - val_loss: 0.3420 - val_precision_1: 1.0000 - val_recall_1: 0.8593 - learning_rate: 5.0000e-05
# Epoch 31/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 803ms/step - accuracy: 0.9762 - loss: 0.1434 - precision_1: 0.9936 - recall_1: 0.9739 - val_accuracy: 0.9143 - val_loss: 0.3082 - val_precision_1: 0.9000 - val_recall_1: 0.9983 - learning_rate: 5.0000e-05
# Epoch 32/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 813ms/step - accuracy: 0.9729 - loss: 0.1316 - precision_1: 0.9940 - recall_1: 0.9698 - val_accuracy: 0.9476 - val_loss: 0.1889 - val_precision_1: 0.9963 - val_recall_1: 0.9317 - learning_rate: 5.0000e-05
# Epoch 33/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 810ms/step - accuracy: 0.9753 - loss: 0.1170 - precision_1: 0.9955 - recall_1: 0.9711 - val_accuracy: 0.9501 - val_loss: 0.1970 - val_precision_1: 0.9982 - val_recall_1: 0.9350 - learning_rate: 5.0000e-05
# Epoch 34/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 810ms/step - accuracy: 0.9748 - loss: 0.1105 - precision_1: 0.9934 - recall_1: 0.9726 - val_accuracy: 0.9629 - val_loss: 0.1566 - val_precision_1: 1.0000 - val_recall_1: 0.9500 - learning_rate: 5.0000e-05
# Epoch 35/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 803ms/step - accuracy: 0.9733 - loss: 0.1064 - precision_1: 0.9942 - recall_1: 0.9700 - val_accuracy: 0.9194 - val_loss: 0.3310 - val_precision_1: 0.9981 - val_recall_1: 0.8937 - learning_rate: 5.0000e-05
# Epoch 36/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 802ms/step - accuracy: 0.9761 - loss: 0.1008 - precision_1: 0.9927 - recall_1: 0.9748 - val_accuracy: 0.8836 - val_loss: 0.5150 - val_precision_1: 0.8653 - val_recall_1: 0.9983 - learning_rate: 5.0000e-05
# Epoch 37/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 803ms/step - accuracy: 0.9717 - loss: 0.1042 - precision_1: 0.9918 - recall_1: 0.9706 - val_accuracy: 0.6995 - val_loss: 1.0913 - val_precision_1: 1.0000 - val_recall_1: 0.5927 - learning_rate: 5.0000e-05
# Epoch 38/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 814ms/step - accuracy: 0.9776 - loss: 0.0850 - precision_1: 0.9962 - recall_1: 0.9736 - val_accuracy: 0.9642 - val_loss: 0.1236 - val_precision_1: 0.9930 - val_recall_1: 0.9592 - learning_rate: 5.0000e-05
# Epoch 39/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 805ms/step - accuracy: 0.9799 - loss: 0.0806 - precision_1: 0.9957 - recall_1: 0.9774 - val_accuracy: 0.9450 - val_loss: 0.2291 - val_precision_1: 0.9943 - val_recall_1: 0.9293 - learning_rate: 5.0000e-05
# Epoch 40/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 810ms/step - accuracy: 0.9788 - loss: 0.0818 - precision_1: 0.9946 - recall_1: 0.9763 - val_accuracy: 0.9795 - val_loss: 0.0969 - val_precision_1: 0.9862 - val_recall_1: 0.9862 - learning_rate: 5.0000e-05
# Epoch 41/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 799ms/step - accuracy: 0.9781 - loss: 0.0761 - precision_1: 0.9948 - recall_1: 0.9757 - val_accuracy: 0.9731 - val_loss: 0.1111 - val_precision_1: 0.9894 - val_recall_1: 0.9739 - learning_rate: 5.0000e-05
# Epoch 42/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 805ms/step - accuracy: 0.9782 - loss: 0.0727 - precision_1: 0.9934 - recall_1: 0.9769 - val_accuracy: 0.8798 - val_loss: 0.3616 - val_precision_1: 1.0000 - val_recall_1: 0.8382 - learning_rate: 5.0000e-05
# Epoch 43/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 804ms/step - accuracy: 0.9825 - loss: 0.0599 - precision_1: 0.9973 - recall_1: 0.9791 - val_accuracy: 0.9565 - val_loss: 0.1194 - val_precision_1: 0.9982 - val_recall_1: 0.9429 - learning_rate: 5.0000e-05
# Epoch 44/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 807ms/step - accuracy: 0.9821 - loss: 0.0675 - precision_1: 0.9963 - recall_1: 0.9792 - val_accuracy: 0.9744 - val_loss: 0.0852 - val_precision_1: 0.9796 - val_recall_1: 0.9863 - learning_rate: 5.0000e-05
# Epoch 45/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 799ms/step - accuracy: 0.9865 - loss: 0.0600 - precision_1: 0.9957 - recall_1: 0.9863 - val_accuracy: 0.9488 - val_loss: 0.1537 - val_precision_1: 0.9770 - val_recall_1: 0.9533 - learning_rate: 5.0000e-05
# Epoch 46/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 798ms/step - accuracy: 0.9828 - loss: 0.0626 - precision_1: 0.9970 - recall_1: 0.9799 - val_accuracy: 0.9246 - val_loss: 0.1927 - val_precision_1: 0.9080 - val_recall_1: 1.0000 - learning_rate: 5.0000e-05
# Epoch 47/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 807ms/step - accuracy: 0.9872 - loss: 0.0454 - precision_1: 0.9986 - recall_1: 0.9840 - val_accuracy: 0.9578 - val_loss: 0.1206 - val_precision_1: 0.9982 - val_recall_1: 0.9448 - learning_rate: 5.0000e-05
# Epoch 48/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 810ms/step - accuracy: 0.9819 - loss: 0.0554 - precision_1: 0.9956 - recall_1: 0.9798 - val_accuracy: 0.9770 - val_loss: 0.0774 - val_precision_1: 0.9964 - val_recall_1: 0.9722 - learning_rate: 5.0000e-05
# Epoch 49/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 803ms/step - accuracy: 0.9861 - loss: 0.0475 - precision_1: 0.9972 - recall_1: 0.9842 - val_accuracy: 0.9194 - val_loss: 0.2331 - val_precision_1: 1.0000 - val_recall_1: 0.8901 - learning_rate: 5.0000e-05
# Epoch 50/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 809ms/step - accuracy: 0.9798 - loss: 0.0552 - precision_1: 0.9955 - recall_1: 0.9770 - val_accuracy: 0.9795 - val_loss: 0.0843 - val_precision_1: 0.9930 - val_recall_1: 0.9794 - learning_rate: 5.0000e-05
# Epoch 51/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 803ms/step - accuracy: 0.9837 - loss: 0.0549 - precision_1: 0.9971 - recall_1: 0.9807 - val_accuracy: 0.9680 - val_loss: 0.0886 - val_precision_1: 0.9605 - val_recall_1: 0.9983 - learning_rate: 5.0000e-05
# Epoch 52/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 800ms/step - accuracy: 0.9749 - loss: 0.0616 - precision_1: 0.9936 - recall_1: 0.9726 - val_accuracy: 0.9003 - val_loss: 0.3248 - val_precision_1: 0.9981 - val_recall_1: 0.8710 - learning_rate: 5.0000e-05
# Epoch 53/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 99s 841ms/step - accuracy: 0.9718 - loss: 0.0754 - precision_1: 0.9948 - recall_1: 0.9672 - val_accuracy: 0.9821 - val_loss: 0.0910 - val_precision_1: 0.9897 - val_recall_1: 0.9863 - learning_rate: 5.0000e-05
# Epoch 54/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 814ms/step - accuracy: 0.9746 - loss: 0.0672 - precision_1: 0.9920 - recall_1: 0.9738 - val_accuracy: 0.9744 - val_loss: 0.0872 - val_precision_1: 0.9928 - val_recall_1: 0.9716 - learning_rate: 1.0000e-05
# Epoch 55/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 808ms/step - accuracy: 0.9875 - loss: 0.0432 - precision_1: 0.9963 - recall_1: 0.9869 - val_accuracy: 0.9783 - val_loss: 0.0779 - val_precision_1: 0.9793 - val_recall_1: 0.9913 - learning_rate: 1.0000e-05
# Epoch 56/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 802ms/step - accuracy: 0.9867 - loss: 0.0467 - precision_1: 0.9950 - recall_1: 0.9869 - val_accuracy: 0.9629 - val_loss: 0.1217 - val_precision_1: 0.9964 - val_recall_1: 0.9533 - learning_rate: 1.0000e-05
# Epoch 57/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 814ms/step - accuracy: 0.9856 - loss: 0.0444 - precision_1: 0.9970 - recall_1: 0.9837 - val_accuracy: 0.9795 - val_loss: 0.0803 - val_precision_1: 0.9982 - val_recall_1: 0.9733 - learning_rate: 1.0000e-05
# Epoch 58/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 811ms/step - accuracy: 0.9847 - loss: 0.0436 - precision_1: 0.9963 - recall_1: 0.9827 - val_accuracy: 0.9744 - val_loss: 0.0976 - val_precision_1: 0.9715 - val_recall_1: 0.9949 - learning_rate: 1.0000e-05
# Epoch 59/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 806ms/step - accuracy: 0.9917 - loss: 0.0329 - precision_1: 0.9982 - recall_1: 0.9906 - val_accuracy: 0.9680 - val_loss: 0.1028 - val_precision_1: 0.9982 - val_recall_1: 0.9590 - learning_rate: 5.0000e-06
# Epoch 60/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 807ms/step - accuracy: 0.9915 - loss: 0.0325 - precision_1: 0.9977 - recall_1: 0.9909 - val_accuracy: 0.9795 - val_loss: 0.0676 - val_precision_1: 0.9947 - val_recall_1: 0.9773 - learning_rate: 5.0000e-06
# Epoch 61/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 813ms/step - accuracy: 0.9902 - loss: 0.0403 - precision_1: 0.9966 - recall_1: 0.9903 - val_accuracy: 0.9795 - val_loss: 0.0743 - val_precision_1: 1.0000 - val_recall_1: 0.9728 - learning_rate: 5.0000e-06
# Epoch 62/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 802ms/step - accuracy: 0.9881 - loss: 0.0364 - precision_1: 0.9973 - recall_1: 0.9869 - val_accuracy: 0.9795 - val_loss: 0.0618 - val_precision_1: 0.9933 - val_recall_1: 0.9800 - learning_rate: 5.0000e-06
# Epoch 63/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 800ms/step - accuracy: 0.9947 - loss: 0.0275 - precision_1: 0.9985 - recall_1: 0.9945 - val_accuracy: 0.9437 - val_loss: 0.2173 - val_precision_1: 1.0000 - val_recall_1: 0.9231 - learning_rate: 5.0000e-06
# Epoch 64/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 794ms/step - accuracy: 0.9867 - loss: 0.0313 - precision_1: 0.9994 - recall_1: 0.9831 - val_accuracy: 0.9731 - val_loss: 0.0794 - val_precision_1: 0.9965 - val_recall_1: 0.9674 - learning_rate: 5.0000e-06
# Epoch 65/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 805ms/step - accuracy: 0.9927 - loss: 0.0288 - precision_1: 0.9985 - recall_1: 0.9916 - val_accuracy: 0.9783 - val_loss: 0.0653 - val_precision_1: 0.9807 - val_recall_1: 0.9894 - learning_rate: 5.0000e-06
# Epoch 66/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 801ms/step - accuracy: 0.9926 - loss: 0.0355 - precision_1: 0.9980 - recall_1: 0.9920 - val_accuracy: 0.9757 - val_loss: 0.0745 - val_precision_1: 0.9714 - val_recall_1: 0.9965 - learning_rate: 5.0000e-06
# Epoch 67/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 808ms/step - accuracy: 0.9921 - loss: 0.0309 - precision_1: 0.9976 - recall_1: 0.9917 - val_accuracy: 0.9757 - val_loss: 0.0915 - val_precision_1: 1.0000 - val_recall_1: 0.9676 - learning_rate: 5.0000e-06
# Epoch 68/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 101s 862ms/step - accuracy: 0.9895 - loss: 0.0357 - precision_1: 0.9974 - recall_1: 0.9886 - val_accuracy: 0.9847 - val_loss: 0.0572 - val_precision_1: 0.9965 - val_recall_1: 0.9828 - learning_rate: 5.0000e-06
# Epoch 69/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 97s 818ms/step - accuracy: 0.9941 - loss: 0.0282 - precision_1: 0.9972 - recall_1: 0.9949 - val_accuracy: 0.9706 - val_loss: 0.0920 - val_precision_1: 0.9982 - val_recall_1: 0.9628 - learning_rate: 5.0000e-06
# Epoch 70/70
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 802ms/step - accuracy: 0.9916 - loss: 0.0367 - precision_1: 0.9975 - recall_1: 0.9911 - val_accuracy: 0.9821 - val_loss: 0.0638 - val_precision_1: 0.9947 - val_recall_1: 0.9809 - learning_rate: 5.0000e-06
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 16s 328ms/step - accuracy: 0.9810 - loss: 0.0700 - precision_1: 0.9968 - recall_1: 0.9774
# Validation Accuracy After Restoring Best Weights: 0.9872, Loss: 0.0575, Precision: 0.9948, Recall: 0.9880
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 291ms/step - accuracy: 0.9327 - loss: 0.2676 - precision_1: 0.5729 - recall_1: 0.6538
# Test Accuracy: 0.9519, Precision: 0.9487, Recall: 0.9737
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step
# Confusion Matrix:
# [[212  22]
#  [ 13 377]]
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#       NORMAL       0.94      0.91      0.92       234
#    PNEUMONIA       0.94      0.97      0.96       390
#
#     accuracy                           0.94       624
#    macro avg       0.94      0.94      0.94       624
# weighted avg       0.94      0.94      0.94       624
